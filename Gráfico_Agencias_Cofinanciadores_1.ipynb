# %%
from matplotlib import style
from matplotlib import pyplot as plt
import numpy as np

# %%
style.use('ggplot')

# %%
x,y = np.loadtxt('Agencias2.txt', unpack = True, delimiter = ',', usecols = (0,1), dtype = 'object,int')

# %%
'''Soma = sum(y)
    
a = False
op = -1

Lista_Porcent = []
for i in y:
    x = (i*100/Soma)
    Lista_Porcent.append(int(x))

print(Lista_Porcent)
print(sum(List_Porcent)

while a != True:
    if sum(Lista_Porcent) != 100:
        op += 1
        novo = Lista_Porcent[op] + 1
        Lista_Porcent[op] = novo
    else:
        a = True
        
print(Lista_Porcent)
print(sum(Lista_Porcent))'''
# Out:
# 'Soma = sum(y)\n    \na = False\nop = -1\n\nLista_Porcent = []\nfor i in y:\n    x = (i*100/Soma)\n    Lista_Porcent.append(int(x))\n\nprint(Lista_Porcent)\nprint(sum(List_Porcent)\n\nwhile a != True:\n    if sum(Lista_Porcent) != 100:\n        op += 1\n        novo = Lista_Porcent[op] + 1\n        Lista_Porcent[op] = novo\n    else:\n        a = True\n        \nprint(Lista_Porcent)\nprint(sum(Lista_Porcent))'

# %%
Soma = sum(y)

Lista_Porcent = []
for i in y:
    c = (i*100/Soma)
    Lista_Porcent.append(int(c))
    
print(Lista_Porcent)
Soma2 = sum(Lista_Porcent)
print(Soma2)

a = False
op = -1

while a == False:
    if Soma2 != 100:
        op += 1
        novo = ((Lista_Porcent[op]) + 1)
        Lista_Porcent[op] = novo
        Soma2 = sum(Lista_Porcent)
    else: 
        a = True
        
print(Lista_Porcent)
print(Soma2)

Lista_Outros = [Lista_Porcent[4],Lista_Porcent[5],Lista_Porcent[6],Lista_Porcent[7],Lista_Porcent[8],Lista_Porcent[9],Lista_Porcent[10],Lista_Porcent[11]]
Outros = sum(Lista_Outros)
print(Outros)
# Out:
# [35, 26, 7, 7, 2, 2, 1, 1, 1, 1, 1, 12]
# 96
# [36, 27, 8, 8, 2, 2, 1, 1, 1, 1, 1, 12]
# 100
# 21

# %%
plt.pie(y, labels = x, explode = (0.2,0.2,0.2,0.2,0.9,0.9,0.9,0.9,0.9,0.9,0.9,0.2), shadow = 'bool', rotatelabels = True, colors = ('c','royalblue','darkcyan','cadetblue','chocolate','chocolate','chocolate','chocolate','chocolate','chocolate','chocolate','chocolate'))
plt.legend(['CNPq + CAPES ({}%)'.format(Lista_Porcent[0]),'CNPq + FAPESP ({}%)'.format(Lista_Porcent[1]),'CNPq + FAPERJ ({}%)'.format(Lista_Porcent[2]),'CNPq + FAPMIG ({}%)'.format(Lista_Porcent[3]),'CNPq + Outros ({}%)'.format(Outros)], bbox_to_anchor = (1.1,1.1))
# segunda parte

# %%
soma_lista = sum(y)
print(y)
print(soma_lista)
# Out:
# [58473 42899 12431 11742  4809  3604  1818  1776  1758  1687  1653 21081]
# 163731

# %%
for i in y:
    porcentagem = ((i*100)/soma_lista )
    print(porcentagem)
# Out:
# 35.71284607068912
# 26.20090270016063
# 7.592331323939877
# 7.171519138098466
# 2.9371346904373636
# 2.201171433631994
# 1.1103578430474377
# 1.084706011689906
# 1.0737123696795354
# 1.0303485595275177
# 1.0095827912857065
# 12.875387067812449
